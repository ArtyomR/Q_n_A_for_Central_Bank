# %% [markdown]
# <a href="https://colab.research.google.com/github/ArtyomR/Q_n_A_for_Central_Bank/blob/main/parcing_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# %% [markdown]
# предварительно заходим в консоль браузера на сайте ЦБ, вводим заклинание:
#
#
# // Получаем список всех ссылок со страницы:
#
# links = document.querySelectorAll('a[href]');
#
#
# // Перебираем найденные ссылки в цикле:
#
# for (var n = 0; n < links.length; n++) {
#
# 	// Если ссылка ведет на текущий сайт (внутренняя):
#
# 	if (new URL(links[n].href)['host'] == location.host) {
#
# 		// Скачиваем html-код по этой ссылке:
#
# 		html = await (await fetch(links[n].href)).text();
#
# 		// Парсим этот html-код:
#
# 		doc = new DOMParser().parseFromString(html, 'text/html');
#
# 		// Ищем в спарсеном коде все pdf-ки:
#
# 		pdfs = doc.querySelectorAll('a[href$=".pdf"]');
#
# 		// Перебираем найденные pdf-ки в цикле:
#
# 		for (var i = 0; i < pdfs.length; i++) {
#
# 			// Выводим ссылку в консоли:
# 			console.log(pdfs[i].href);
#
# 		}
#
# 	}
#
# }
#
# получаем все ссылки на пдфки и заносим в таблицу, что подключаем далее

# %%
db = pd.read_excel('Новая таблица-8.xlsx', header = None)
db
# Out:
#                                                       0
# 0     https://cbr.ru/Content/Document/File/134865/pl...
# 1     https://cbr.ru/Collection/Collection/File/4387...
# 2     https://cbr.ru/Content/Document/File/155957/on...
# 3     https://cbr.ru/Content/Document/File/119613/on...
# 4     https://cbr.ru/Content/Document/File/120709/Su...
# ...                                                 ...
# 3799  https://cbr.ru/Collection/Collection/File/4387...
# 3800  https://cbr.ru/Content/Document/File/155957/on...
# 3801  https://cbr.ru/Content/Document/File/119613/on...
# 3802  https://cbr.ru/Content/Document/File/120709/Su...
# 3803  https://cbr.ru/Content/Document/File/143838/db...
#
# [3804 rows x 1 columns]

# %%
urls = db.values.tolist()
urls[1][0]
len(urls)
# Out:
# 3804

# %%
for url in urls:
  print(url)
# Out:
# ['https://cbr.ru/Content/Document/File/134865/plan_limit.pdf']
# ['https://cbr.ru/Collection/Collection/File/43872/ar_2022.pdf']
# ['https://cbr.ru/Content/Document/File/155957/onrfr_2024-26.pdf']
# ['https://cbr.ru/Content/Document/File/119613/onrndo_2021-2025.pdf']
# ['https://cbr.ru/Content/Document/File/120709/SupTech_RegTech_2021-2023.pdf']
# ['https://cbr.ru/Content/Document/File/143838/dbra_20221227.pdf']
# ['https://cbr.ru/Collection/Collection/File/43872/ar_2022.pdf']
# ['https://cbr.ru/Content/Document/File/155957/onrfr_2024-26.pdf']
# ['https://cbr.ru/Content/Document/File/119613/onrndo_2021-2025.pdf']
# ['https://cbr.ru/Content/Document/File/120709/SupTech_RegTech_2021-2023.pdf']
# ['https://cbr.ru/Content/Document/File/143838/dbra_20221227.pdf']
# ['https://cbr.ru/Collection/Collection/File/43872/ar_2022.pdf']
# ['https://cbr.ru/Content/Document/File/155957/onrfr_2024-26.pdf']
# ['https://cbr.ru/Content/Document/File/119613/onrndo_2021-2025.pdf']
# ...

# %%
for i in range(0, 3804):
  r = requests.get(urls[i][0])

  with open( 'file'+ str(i)+'.pdf', 'wb') as f:
      f.write(r.content)
# Out:
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# <ipython-input-98-0b36a8da94f4> in <cell line: 1>()
#       1 for i in range(64, 3804):
# ----> 2   r = requests.get(urls[i][0])
#       3
#       4   with open( 'file'+ str(i)+'.pdf', 'wb') as f:
#       5       f.write(r.content)
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ...

# %%
# !pip install PyPDF2
# !pip install aspose
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 4.3 MB/s eta 0:00:00
# ...
# ERROR: Could not find a version that satisfies the requirement aspose (from versions: none)
# ERROR: No matching distribution found for aspose

# %%
import PyPDF2

texts = []


for i in range(3804)
  pdf_file = open('file'+str(i)+'.pdf', 'rb')  # Открываем файл в режиме чтения бинарных данных
  pdf_reader = PyPDF2.PdfFileReader(pdf_file)  # Создаем объект PdfFileReader
  num_pages = pdf_reader.numPages  # Получаем количество страниц в файле

  for page in range(num_pages):
    pdf_page = pdf_reader.getPage(page)  # Получаем страницу
    #texts.append(pdf_page.extractText())
    #print(pdf_page.extractText())  # Выводим текст страницы

  pdf_file.close()

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !pip install aspose-words
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 MB 6.8 MB/s eta 0:00:00
# ...

# %%
import aspose.words as aw

# Загрузить PDF-файл
doc = aw.Document("file1.pdf")

# Сохранить PDF как TXT
doc.save("/content/drive/MyDrive/Mechanics+1/pdf-to-text.txt")

# %%
# !pip install 'PyPDF2<3.0'
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.8/222.8 kB 5.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: PyPDF2
#     Found existing installation: PyPDF2 3.0.1
#     Uninstalling PyPDF2-3.0.1:
#       Successfully uninstalled PyPDF2-3.0.1
# ...

# %%
import PyPDF2

texts = []



pdf_file = open('file'+str(1)+'.pdf', 'rb')  # Открываем файл в режиме чтения бинарных данных
pdf_reader = PyPDF2.PdfFileReader(pdf_file)  # Создаем объект PdfFileReader
num_pages = pdf_reader.numPages  # Получаем количество страниц в файле
for page in range(num_pages):
  pdf_page = pdf_reader.getPage(page)  # Получаем страницу
  #texts.append(pdf_page.extractText())
  print(pdf_page.extractText())  # Выводим текст страницы

  pdf_file.close()
# Out:
# ---------------------------------------------------------------------------
# DeprecationError                          Traceback (most recent call last)
# <ipython-input-5-ca0d42ec447b> in <cell line: 8>()
#       6
#       7 pdf_file = open('file'+str(1)+'.pdf', 'rb')  # Открываем файл в режиме чтения бинарных данных
# ----> 8 pdf_reader = PyPDF2.PdfFileReader(pdf_file)  # Создаем объект PdfFileReader
#       9 num_pages = pdf_reader.numPages  # Получаем количество страниц в файле
#      10 for page in range(num_pages):
#
# /usr/local/lib/python3.10/dist-packages/PyPDF2/_reader.py in __init__(self, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/PyPDF2/_utils.py in deprecation_with_replacement(old_name, new_name, removed_in)
#     367       an error case, e.g. the PDF being completely broken.
#     368     - warnings.warn should be used if the user needs to fix their code, e.g.
# --> 369       DeprecationWarnings
# ...
